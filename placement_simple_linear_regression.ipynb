# %%
import pandas as pd

# %%
df=pd.read_csv('placement.csv')

# %%
df.head(5)

# %%
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %%
X=df['cgpa']
y=df['package']
X=pd.DataFrame(X)
y=pd.DataFrame(y)
type(X)
type(y)
#X=df.drop('package',axis=1) # Independed variable

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X,y)  # To Train model

# %%
cg=float(input('Enter your CGPA'))
result=model.predict([[cg]])
print("Predicated Pacakge : ",result)
